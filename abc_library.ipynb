# %%
#                          LIBRARY MANAGEMENT SYSTEM

import os
import pymysql
import pandas as pd
import getpass


host = os.getenv('MYSQL_HOST')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
database = os.getenv('MYSQL_DATABASE')


con = pymysql.connect(host=host, port=int(3306), user="root", passwd="Shreeki@05", db="Lib", charset="utf8mb4")
c=con.cursor()
q='use Lib'
c.execute(q)
df = pd.read_sql_query("SELECT * FROM books_10",con)

#----------------------------------------------------------------------------------------------------------------------------

def addbook():
    bookname = input("Enter BOOK Name: ")
    code = input("Enter BOOK Code: ") 
    total_books = input("Enter Total Number of Books: ")
    subject = input("Enter Subject: ")
    data = (bookname,code,total_books,subject)
    sql = 'insert into books_10 values(%s,%s,%s,%s)'
    c = con.cursor()
    c.execute(sql,data)
    con.commit()
    print(">------------------------------------------------<")
    print("Data Entered Successfully")
    x=input("if u want to continue press y :").lower()
    if x=="y":
        main()

def issueb():
    payment_amount = int(input("Enter The Library fee you paid (Total fee is 1000rs): "))
    if payment_amount >= 1000:
        print("Payment received. You can use the library.")
        
        name = input("Enter Your Name: ")
        regno = input("Enter Your Reg No: ")
        code = input("Enter The Book Code You Want: ")
        date = input("Enter Date In The Format (dd/mm/yyyy): ")
        a = "insert into issue_10 values(%s,%s,%s,%s,%s)"
        data = (payment_amount,name,regno,code,date)
        c = con.cursor()
        c.execute(a,data)
        con.commit()
        print(">------------------------------------------------<")
        print("Book issued to : ",name)
        bookup(code,-1)
    else:
        print("Please pay the full amount (1000rs) to use the library.")
    
    x=input("if u want to continue press y :").lower()
    if x=="y":
        main()
                
def submitb():
    name = input("Enter Your Name: ")
    regno = input("Enter Your Reg No: ")
    code = input("Enter The Book Code: ")
    date = input("Enter Date In The Format (dd/mm/yyyy):")
    a = "insert into submit_10 values(%s,%s,%s,%s)"
    data = (name,regno,code,date)
    c = con.cursor()
    c.execute(a,data)
    con.commit()
    print(">----------------------------------------------<")
    print("Book Submitted from : ",name)
    bookup(code,1)
    
    x=input("if u want to continue press y :").lower()
    if x=="y":
        main()
          
def bookup(co,u):
    a = "select TOTAL from books_10 where BCODE=%s"
    data = (co,)
    c = con.cursor()
    c.execute(a,data)
    myresult = c.fetchone()
    t = myresult[0] + u
    sql = "update books_10 set TOTAL = %s where BCODE = %s"
    d = (t,co)
    c.execute(sql,d)
    con.commit()
    
    x=input("if u want to continue press y :").lower()
    if x=="y":
        main()

    
def dbook():
    ac = input("Enter Book Code: ")
    a = "delete from books_10 where BCODE = %s"
    data = (ac,)
    c = con.cursor()
    c.execute(a,data)
    con.commit()
    
    x=input("if u want to continue press y :").lower()
    if x=="y":
        main()
    
    
def dispbook():
    a = "select * from books_10" 
    c = con.cursor()
    c.execute(a)
    myresult = c.fetchall()
    for i in myresult:
        print("Book Name : ",i[0])
        print("Book Code: ",i[1])
        print("Total: ",i[2])
        print(">----------------------------------------------<")
    
    x=input("if u want to continue press y :").lower()
    if x=="y":
        main()


    
def main():
    
    print("""

            1. ADD BOOK

            2. ISSUE BOOK

            3. SUBMIT BOOK

            4. DELETE BOOK

            5. DISPLAY BOOKS
                                """)

    choice = input("Enter Task No: ")
    print(">-------------------------------------------------<")

    if (choice == '1'):
        addbook()
    elif (choice=='2'):
        issueb()
    elif (choice=='3'):
        submitb()
    elif (choice=='4'):
        dbook()
    elif (choice=='5'):
        dispbook()
    else:
        print(" Wrong choice...........")
        x=input("if u want to continue press y :").lower()
        if x=="y":
            main()

    
    
      
def pswd():
    ps = getpass.getpass(prompt='Enter your password: ') 
    if ps == "py151":
        main()
    else:
        print("Wrong Password")
        pswd()
    
pswd()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# Enter your password: ········
#
#
#             1. ADD BOOK
#
#             2. ISSUE BOOK
#
#             3. SUBMIT BOOK
#
#             4. DELETE BOOK
#
#             5. DISPLAY BOOKS
#
# Enter Task No: 1
# >-------------------------------------------------<
# Enter BOOK Name: def
# Enter BOOK Code: 2
# Enter Total Number of Books: 10
# Enter Subject: English
# >------------------------------------------------<
# Data Entered Successfully
# if u want to continue press y :y
#
#
#             1. ADD BOOK
#
#             2. ISSUE BOOK
#
#             3. SUBMIT BOOK
#
#             4. DELETE BOOK
#
#             5. DISPLAY BOOKS
#
# Enter Task No: 2
# >-------------------------------------------------<
# ...
